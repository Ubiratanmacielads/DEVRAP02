# %% [markdown]
# <a href="https://colab.research.google.com/github/Ubiratanmacielads/DEVRAP02/blob/main/exerc_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 01 de DEV Rapido em Python

# %%
import pandas as pd

# %%
grupos = ['produto a', 'produto b', 'produto c']
valores = [ 1, 10, 100]

# %%
#criando um dicionario de dados
dict_test = {
    "Nome"   : ["JOao",    "Maria", "JOsé", " Silvio", "Patricia", "Leonides", "Kayo", "morgana","Flavio", "Elisson", "Helena"],
    "Genero" : ["Masc", "Feminino", "Masc",    "Masc", "FEminino", "Masc", "Masc","fem","Masc","Homem", "Mulher"]    ,
    "Idade"  : [    52,         47,     65,        34,         20,         26, 38, 24, 31, 22, 18],
    "UF"     : ["PE" ,        "PE",   "PB",      "RN",       "PB",   "PE", "PE", "PE","PE", "PE", "SP" ]
}

# %%
df = pd.DataFrame(dict_test)

# %%
df.head()
# Out:
#        Nome    Genero  Idade  UF
# 0      JOao      Masc     52  PE
# 1     Maria  Feminino     47  PE
# 2      JOsé      Masc     65  PB
# 3    Silvio      Masc     34  RN
# 4  Patricia  FEminino     20  PB

# %%
df.tail()
# Out:
#        Nome  Genero  Idade  UF
# 6      Kayo    Masc     38  PE
# 7   morgana     fem     24  PE
# 8    Flavio    Masc     31  PE
# 9   Elisson   Homem     22  PE
# 10   Helena  Mulher     18  SP

# %%
df.tail(15)
# Out:
#         Nome    Genero  Idade  UF
# 0       JOao      Masc     52  PE
# 1      Maria  Feminino     47  PE
# 2       JOsé      Masc     65  PB
# 3     Silvio      Masc     34  RN
# 4   Patricia  FEminino     20  PB
# 5   Leonides      Masc     26  PE
# 6       Kayo      Masc     38  PE
# 7    morgana       fem     24  PE
# 8     Flavio      Masc     31  PE
# 9    Elisson     Homem     22  PE
# 10    Helena    Mulher     18  SP

# %%
df.describe()
# Out:
#            Idade
# count  11.000000
# mean   34.272727
# std    14.960554
# min    18.000000
# 25%    23.000000
# 50%    31.000000
# 75%    42.500000
# max    65.000000

# %%
df.columns
# Out:
# Index(['Nome', 'Genero', 'Idade', 'UF'], dtype='object')

# %%
df.count()
# Out:
# Nome      11
# Genero    11
# Idade     11
# UF        11
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    11 non-null     object
#  1   Genero  11 non-null     object
#  2   Idade   11 non-null     int64
#  3   UF      11 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 480.0+ bytes

# %%
df.shape
# Out:
# (11, 4)

# %%
df.sample(8)
# Out:
#         Nome    Genero  Idade  UF
# 4   Patricia  FEminino     20  PB
# 5   Leonides      Masc     26  PE
# 10    Helena    Mulher     18  SP
# 3     Silvio      Masc     34  RN
# 1      Maria  Feminino     47  PE
# 6       Kayo      Masc     38  PE
# 2       JOsé      Masc     65  PB
# 7    morgana       fem     24  PE
